# %% [markdown]
# **Regras de associação**
#
# **Algoritmo Apriori**
#
# **Veja: https://www.youtube.com/watch?v=0v6PiOpsJi8**

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5975 sha256=244dcfa8128e9515d32a6797c3e230dd49dcbb5eb30cee1b09e39b5b68b37e3c
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
import pandas as pd
from apyori import apriori

# %%
#encoding = "cp1252", encoding='utf-8', encoding='latin1'etc
base= pd.read_csv('/content/binned.csv', ',',encoding="ISO-8859-1")
base
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Unnamed: 0          precipitation          temp_max          temp_min  \
# 0              0  precipitation_range_1  temp_max_range_2  temp_min_range_3
# 1              1  precipitation_range_2  temp_max_range_2  temp_min_range_2
# 2              2  precipitation_range_1  temp_max_range_2  temp_min_range_3
# 3              3  precipitation_range_3  temp_max_range_2  temp_min_range_3
# 4              4  precipitation_range_1  temp_max_range_2  temp_min_range_2
# ...          ...                    ...               ...               ...
# 3200        3200  precipitation_range_2  temp_max_range_2  temp_min_range_2
# 3201        3201  precipitation_range_1  temp_max_range_2  temp_min_range_2
# 3202        3202  precipitation_range_1  temp_max_range_2  temp_min_range_2
# 3203        3203  precipitation_range_2  temp_max_range_1  temp_min_range_2
# 3204        3204  precipitation_range_1  temp_max_range_4  temp_min_range_5
#
#               wind
# 0     wind_range_2
# 1     wind_range_2
# 2     wind_range_1
# 3     wind_range_2
# 4     wind_range_3
# ...            ...
# 3200  wind_range_2
# 3201  wind_range_2
# 3202  wind_range_2
# 3203  wind_range_2
# 3204  wind_range_2
#
# [3205 rows x 5 columns]

# %%
base.shape
# Out:
# (3205, 5)

# %% [markdown]
# **Como estaremos treinando um modelo a priori, que recebe entradas em formato de lista, precisamos transformar o dataframe em uma lista de transações.**

# %%
transacoes = []
for i in range(len(base)):
  #print(i)
  #print(base_mercado1.values[i, 0])
  transacoes.append([str(base.values[i, j]) for j in range(base.shape[1])])

# %%
transacoes
# Out:
# [['0',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['1',
#   'precipitation_range_2',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['2',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_1'],
#  ['3',
#   'precipitation_range_3',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['4',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['5',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['6',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['7',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['8',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['9',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['10',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['11',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['12',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_1',
#   'wind_range_1'],
#  ['13',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['14',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_1',
#   'wind_range_2'],
#  ['15',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_1',
#   'wind_range_3'],
#  ['16',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['17',
#   'precipitation_range_3',
#   'temp_max_range_1',
#   'temp_min_range_1',
#   'wind_range_3'],
#  ['18',
#   'precipitation_range_2',
#   'temp_max_range_1',
#   'temp_min_range_1',
#   'wind_range_1'],
#  ['19',
#   'precipitation_range_2',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['20',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_4'],
#  ['21',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['22',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['23',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['24',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_3'],
#  ['25',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['26',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_1',
#   'wind_range_1'],
#  ['27',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['28',
#   'precipitation_range_3',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['29',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_3'],
#  ['30',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['31',
#   'precipitation_range_2',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['32',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['33',
#   'precipitation_range_1',
#   'temp_max_range_3',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['34',
#   'precipitation_range_1',
#   'temp_max_range_3',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['35',
#   'precipitation_range_1',
#   'temp_max_range_3',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['36',
#   'precipitation_range_1',
#   'temp_max_range_3',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['37',
#   'precipitation_range_1',
#   'temp_max_range_3',
#   'temp_min_range_3',
#   'wind_range_3'],
#  ['38',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['39',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_1'],
#  ['40',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['41',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['42',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_1'],
#  ['43',
#   'precipitation_range_2',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_1'],
#  ['44',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['45',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['46',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_1'],
#  ['47',
#   'precipitation_range_2',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['48',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_4'],
#  ['49',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['50',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['51',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_4'],
#  ['52',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['53',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['54',
#   'precipitation_range_2',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['55',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['56',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['57',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_1',
#   'wind_range_2'],
#  ['58',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['59',
#   'precipitation_range_1',
#   'temp_max_range_1',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['60',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['61',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_3'],
#  ['62',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_3'],
#  ['63',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_3'],
#  ['64',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_3'],
#  ['65',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['66',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_2',
#   'wind_range_2'],
#  ['67',
#   'precipitation_range_1',
#   'temp_max_range_3',
#   'temp_min_range_2',
#   'wind_range_1'],
#  ['68',
#   'precipitation_range_1',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  ['69',
#   'precipitation_range_2',
#   'temp_max_range_2',
#   'temp_min_range_3',
#   'wind_range_2'],
#  

#   'temp_max_range_3',
#   'temp_min_range_5',
#   'wind_range_2'],
#  ['998',
#   'precipitation_range_1',
#   'temp_max_range_4',
#   'temp_min_range_5',
#   'wind_range_1'],
#  ['999',
#   'precipitation_range_1',
#   'temp_max_range_3',
#   'temp_min_range_5',
#   'wind_range_2'],
#  ...]

# %%
type(transacoes)
# Out:
# list

# %% [markdown]
# **Vamos chamar executar o algoritmo apriori e armazenar as regras obtidas**

# %%
regras = apriori(transacoes, min_support = 0.3, min_confidence = 0.5, min_lift=0.5)
saida = list(regras) 
print(len(saida))
print(saida)
# Out:
# 3
# [RelationRecord(items=frozenset({'precipitation_range_1'}), support=0.8870514820592824, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'precipitation_range_1'}), confidence=0.8870514820592824, lift=1.0)]), RelationRecord(items=frozenset({'wind_range_1', 'precipitation_range_1'}), support=0.4414976599063963, ordered_statistics=[OrderedStatistic(items_base=frozenset({'wind_range_1'}), items_add=frozenset({'precipitation_range_1'}), confidence=0.9778852798894264, lift=1.1023996911873413)]), RelationRecord(items=frozenset({'wind_range_2', 'precipitation_range_1'}), support=0.3541341653666147, ordered_statistics=[OrderedStatistic(items_base=frozenset({'wind_range_2'}), items_add=frozenset({'precipitation_range_1'}), confidence=0.8566037735849058, lift=0.9656753761307151)])]

# %%
print(saida[0])
# Out:
# RelationRecord(items=frozenset({'precipitation_range_1'}), support=0.8870514820592824, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'precipitation_range_1'}), confidence=0.8870514820592824, lift=1.0)])

# %%
print(saida[1])
# Out:
# RelationRecord(items=frozenset({'wind_range_1', 'precipitation_range_1'}), support=0.4414976599063963, ordered_statistics=[OrderedStatistic(items_base=frozenset({'wind_range_1'}), items_add=frozenset({'precipitation_range_1'}), confidence=0.9778852798894264, lift=1.1023996911873413)])

# %% [markdown]
# **Para facilitar a visualização, veja como transformar isso em um dataframe**
#
# Extraído de:
#
# https://www.section.io/engineering-education/apriori-algorithm-in-python/
#
# https://splunktool.com/understanding-apyoris-output

# %%
lhs = []
rhs = []
suporte = []
confianca = []
lift = []

for resultado in saida:
  #print(resultado)
  s = resultado[1]
  #print(s)
  result_rules = resultado[2]
  #print(result_rule)
  for result_rule in result_rules:
    #print(result_rule)
    a = list(result_rule[0])
    b = list(result_rule[1])
    c = result_rule[2]
    l = result_rule[3]
    #print(a, ' - ', b, ' - ', c, ' - ', l)
    lhs.append(a)
    rhs.append(b)
    suporte.append(s)
    confianca.append(c)
    lift.append(l)
    RegrasFinais = pd.DataFrame({'Lhs': lhs, 'Rhs': rhs, 'suporte': suporte, 'confianca': confianca, 'lift': lift})

# %%
RegrasFinais
# Out:
#               Lhs                      Rhs   suporte  confianca      lift
# 0              []  [precipitation_range_1]  0.887051   0.887051  1.000000
# 1  [wind_range_1]  [precipitation_range_1]  0.441498   0.977885  1.102400
# 2  [wind_range_2]  [precipitation_range_1]  0.354134   0.856604  0.965675

# %% [markdown]
# **Podemos ordenar estas regras por uma métrica desejada**

# %%
RegrasFinais.sort_values(by='lift', ascending =False)
# Out:
#               Lhs                      Rhs   suporte  confianca      lift
# 1  [wind_range_1]  [precipitation_range_1]  0.441498   0.977885  1.102400
# 0              []  [precipitation_range_1]  0.887051   0.887051  1.000000
# 2  [wind_range_2]  [precipitation_range_1]  0.354134   0.856604  0.965675
